# %% [markdown]
#  ### 아래 내용은 글로벌 기업 (주)인텔에서 개발한 Intel® AI for Youth Program 내용을
# 한국 Implementation Partner사인 (주)Brain AI와 Brain AI Coach Network에서 <br>
# 우리나라 초, 중, 고 학생들의 AI 교육을 위해 현지화 한 내용입니다. <br>
# (주)Brain AI와 NDA를 체결한 학교에서만 사용 가능하며 NDA를 준수해야합니다. <br>
# 상업적 사용은 불가하며, 학교내에서 학생들 교육활동에 자유롭게 사용가능합니다.

# %% [markdown]
# ## <B>학습 주제: 오픈CV 라이브러리를 이용하여 영상 불러오기
# OpenCV(Open Source Computer Vision)는 실시간 컴퓨터 비전을 목적으로 한 프로그래밍 라이브러리로 인텔이 개발하였다고 합니다. 실시간 이미지 프로세싱에 중점을 둔 라이브러리입니다.
#
# [출처 링크](https://ko.wikipedia.org/wiki/OpenCV#:~:text=OpenCV(Open%20Source%20Computer%20Vision,%EC%A4%91%EC%A0%90%EC%9D%84%20%EB%91%94%20%EB%9D%BC%EC%9D%B4%EB%B8%8C%EB%9F%AC%EB%A6%AC%EC%9D%B4%EB%8B%A4.)

# %% [markdown]
# <img src="https://opencv.org/wp-content/uploads/2022/05/logo.png" alt="https://opencv.org/" width="100" height="132">
#
# [링크](https://docs.opencv.org/4.x/dd/d43/tutorial_py_video_display.html)

# %% [markdown]
# ### 주피터 랩(Jupyter Lab) 사용 방법
#
#
# 키보드의 위쪽 및 아래쪽 화살표 키를 사용하여 위 아래로 이동할 수 있습니다. <br />
# 주피터 랩에서
#  - 코드 블록을 편집하려면 Enter를 누르십시오.
#  - 코드를 실행하려면 코드 블록을 선택하고 <b> Shift + Enter  또는  Ctrl + Enter  를 누릅니다.</b> <br />
#
# 주피터 랩 코드는 누적됩니다. (정의 된 변수는 주피터 랩을 닫을 때까지 계속 사용할 수 있습니다.) <br />
# 따라서 예기치 않은 결과를 피하기 위해 위에서부터 시작하여 아래로 프로그램을 작성하고 실행하십시오!
#
# 주피터 랩 사용에 대한 자세한 도움말을 보려면 위 메뉴에서 도움말을 클릭하세요. <br /> 또는 [여기](https://jupyterlab.readthedocs.io/en/stable/user/interface.html) 을 방문하여 자세히 알아보십시오.<br>
#
# 여러분의 아이디어를 직접 프로그램하고 결과를 확인해보세요. 그것이 가장 빠른 학습 방법 중 하나입니다.

# %% [markdown]
# ### 1. 오픈CV 라이브러리를 이용하여 파이썬에서 이미지를 불러와 출력 해 봅시다.

# %% [markdown]
# * 코드를 작성할 때는 대소문자, 들여쓰기, 문장부호 등을 특히 주의하여 작성합니다.

# %%
import cv2
import numpy as np

img = cv2.imread("images_cv/schoolZone.jpg")
cv2.imshow("Image", img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
from matplotlib import pyplot as plt

img = cv2.imread("images_cv/schoolZone.jpg")

plt.imshow(img)
plt.title('schoolZone')
plt.axis('off')
plt.show()

# %%
from matplotlib import pyplot as plt

img = cv2.imread("images_cv/schoolZone.jpg")
img_cvt = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)


plt.imshow(img_cvt)
plt.title('schoolZone')
plt.axis('off')
plt.show()

# %%
from matplotlib import pyplot as plt

img_grey = cv2.imread('images_cv/Playfield.png', 0)
plt.imshow(img_grey, cmap='gray', interpolation = 'bicubic')
plt.title('Playfield grayscale image')
plt.axis('off')
plt.show()

# %%
import cv2
import numpy as np
import sys

img = cv2.imread("images_cv/Playfield.png")
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2.imshow("Playfield Grey Image", img_gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print(img_gray[0, 100])
# Out:
# 189

# %% [markdown]
# Numpy를 기억하십니까? OpenCV에서 이미지는 Numpy Arrays로 저장됩니다.
#
# 이러한 Array에는 이미지를 빠르게 분석하는 데 사용할 수있는 방법이 내장되어 있습니다. <br>
# 예를 들어 ** .shape **는 이미지가 저장된 Numpy 배열의 크기를 알려줍니다. (높이, 너비, 채널) <br>
# 다른 다양한 고급 배열 조작 기술도 있지만 지금은 간단한 것들을 배우도록 하겠습니다.
#
# 기본적으로 파랑(Blue), 녹색(Green) 및 빨강(Red)의 픽셀 강도를 저장하는 3개의 채널이 있습니다. <br>
# 이것은 OpenCV에서 사용하는 기본 색상 공간입니다.

# %% [markdown]
# ### 2. 오픈CV 라이브러리를 이용하여 파이썬에서 웹캠 영상을 출력 해 봅시다.

# %% [markdown]
# * 코드를 작성할 때는 대소문자, 들여쓰기, 문장부호 등을 특히 주의하여 작성합니다.

# %%
import cv2

# %%
def Main():
    video_capture = cv2.VideoCapture(sourceVideo)
    while(True):
        ret, frame = video_capture.read()
        cv2.imshow('Press q to Exit', frame)

        key = cv2.waitKey(1)
        if key == ord("q"):
            break
            
    video_capture.release() 
    cv2.destroyAllWindows()

# %%
sourceVideo = 0
if __name__ == '__main__': 
    Main()

# %% [markdown]
# * sourceVideo의 0은 무엇을 의미할까요? 1 또는 2의 숫자로 변경하면 어떻게 될까요?
# * 오픈cv 함수에 대해 자세히 알아봅니다.
#   - cv2.VideoCapture()
#   - cv2.imshow()
#   - cv2.waitKey()
#   - cv2.destroyAllWindows()

# %% [markdown]
# error 발생했다면 error의 원인을 찾아 해결합니다. 필요하면 친구들의 도움을 받거나 인터넷 검색 또는 Youtube등을 이용합니다.

# %% [markdown]
# ### 3. 이미지 임계처리 Threshold

# %% [markdown]
# https://opencv-python.readthedocs.io/en/latest/doc/09.imageThresholding/imageThresholding.html

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('images_cv/Playfield.png', 0)

ret, thresh1 = cv2.threshold(img,127,255, cv2.THRESH_BINARY)
ret, thresh2 = cv2.threshold(img,127,255, cv2.THRESH_BINARY_INV)
ret, thresh3 = cv2.threshold(img,127,255, cv2.THRESH_TRUNC)
ret, thresh4 = cv2.threshold(img,127,255, cv2.THRESH_TOZERO)
ret, thresh5 = cv2.threshold(img,127,255, cv2.THRESH_TOZERO_INV)

titles =['Original','BINARY','BINARY_INV','TRUNC','TOZERO','TOZERO_INV']
images = [img, thresh1, thresh2, thresh3, thresh4, thresh5]

for i in range(6):
    plt.subplot(2,3,i+1), plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()

# %%
import cv2
import numpy as np 
from matplotlib import pyplot as plt 

img = cv2.imread('images_cv/Playfield.png',0)
img = cv2.medianBlur(img, 5)
ret, th1 = cv2.threshold(img,127,255,cv2.THRESH_BINARY)
th2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,\
cv2.THRESH_BINARY,9,25)
th3 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
cv2.THRESH_BINARY,9,10)

titles = ['Original','Global','Mean','Gaussian']

images = [img,th1,th2,th3]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i],'gray')
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])

plt.show()
